# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
sample_size=[2**i for i in range(5, 14)]
accuracy_function_1 = [0.9855, 0.9840, 0.9858, 0.9912, 0.9922, 0.9935, 0.9945, 0.9959, 0.9989]
accuracy_function_2 = [0.9952, 0.9869, 0.9790, 0.9829, 0.9504, 0.9523, 0.9759, 0.9802, 0.9871]
accuracy_jacobian_1 = [0.0247, 0.0128, 0.1046, 0.2974, 0.3448, 0.5014, 0.5086, 0.7956, 0.8473]
accuracy_jacobian_2 = [0.5866, -0.4354, 0.6390, 0.6848, 0.4234, 0.6393, 0.8151, 0.9323, 0.9871]

# %%
plt.figure(figsize=(10, 5))
plt.plot(sample_size, accuracy_function_1, label='M- Norm', marker='o')

plt.plot(sample_size, accuracy_function_2, label='M- Norm with Jacobian', marker='.')

plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Sample Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(sample_size, accuracy_function_1, label='M -Norm', marker='o')
plt.plot(sample_size, accuracy_jacobian_1, label='MF -Norm', marker='*')
plt.plot(sample_size, accuracy_function_2, label='M -Norm with Jacobian', marker='.')
plt.plot(sample_size, accuracy_jacobian_2, label='MF -Norm with Jacobian', marker='s')

plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Sample Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
Laten_Dim = [1,5,10,15,20,25,30,35,40,45,50,55,60]
F2_limit = [0.5390,0.8768,0.9495,0.9728,0.9867,0.9942,0.9974,0.9988,0.9995,0.9998,0.9999,0.9999,0.9999]
plt.figure(figsize=(10, 5))
plt.plot(Laten_Dim, F2_limit, label='Jacobian reconstruction accuracy', marker='*') 
plt.xlabel('Latent Dimension')
plt.ylabel('Jacobian reconstruction accuracy')
plt.title(' Jacobian reconstruction accuracy vs Latent Dimension')
plt.legend()
plt.grid(True)
plt.show()

# %%
sample_size=[2**i for i in range(5, 14)]
accuracy_function_400_1 = [0.9860, 0.9846, 0.9901, 0.9950, 0.9937, 0.9945, 0.9981, 0.9993, 0.9992]
accuracy_function_400_2 = [0.9953, 0.9930, 0.9383, 0.9909, 0.9929, 0.9656, 0.9746, 0.9687, 0.9833]
accuracy_function_pre_train = [0.9952, 0.9869, 0.9790, 0.9829, 0.9504, 0.9523, 0.9759, 0.9802, 0.9871]
accuracy_jacobian_400_1 = [0.0552, 0.0115, 0.3059, 0.5457, 0.3683, 0.5203, 0.7980, 0.8422, 0.8595]
accuracy_jacobian_400_2 = [0.5241, 0.0911, 0.6253, 0.6653, 0.4179, 0.6393, 0.6212, 0.8637, 0.8914]
accuracy_jacobian_pre_train = [0.5866, -0.4354, 0.6390, 0.6848, 0.4234, 0.6393, 0.8151, 0.9323, 0.9871]

# %%
plt.figure(figsize=(10, 5))
plt.plot(sample_size, accuracy_function_400_1, label='Model A ($\lambda = 0$)', marker='o')
plt.plot(sample_size, accuracy_function_400_2, label='Model B ($\lambda = 10$)', marker='*')
plt.plot(sample_size, accuracy_function_pre_train, label='Model C (pre-trained) ', marker='.')

plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Sample Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(sample_size, accuracy_jacobian_400_1, label='Model A ($\lambda = 0$)', marker='o')
plt.plot(sample_size, accuracy_jacobian_400_2, label='Model B ($\lambda = 10$)', marker='*')
plt.plot(sample_size, accuracy_jacobian_pre_train, label='Model C (pre-trained)', marker='.')

plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Jacobian Accuracy vs Sample Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(sample_size, accuracy_function_400_1, label='$\lambda = 0$', marker='o')
plt.plot(sample_size, accuracy_function_400_2, label='$\lambda = 10$', marker='*')
plt.plot(sample_size, accuracy_function_pre_train, label='pre-trained', marker='.')
plt.plot(sample_size, accuracy_jacobian_400_1, label='Jac $ \lambda = 0$', marker='s')
plt.plot(sample_size, accuracy_jacobian_400_2, label='Jac $ \lambda = 10$', marker='')
plt.plot(sample_size, accuracy_jacobian_pre_train, label='Jac pre-trained', marker='x')

plt.xlabel('Sample Size')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Sample Size')
plt.legend()
plt.grid(True)
plt.show()
